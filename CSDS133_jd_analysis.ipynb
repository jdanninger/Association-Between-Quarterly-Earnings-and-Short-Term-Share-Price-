# %% [markdown]
# # IF R^2 IS NEGATIVE, MEANS THAT ITS A WORSE FIT THAN A HORIZONTAL LINE

# %% [markdown]
# ## Import stock price info
# - create a difference in stock price table (just for most recent before for now)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
prices = pd.read_csv(r'stockPrice.csv')
pricedif1 = {'price change(%)': ((prices.iloc[:, 2] - prices.iloc[:, 1])/prices.iloc[:, 1])*100}
pricedif1 = pd.DataFrame.from_dict(pricedif1)
pricedif1
# Out:
#        price change(%)
# AAPL          6.977762
# MSFT          2.849317
# GOOG          7.367353
# AMZN         13.535914
# TSLA          3.231684
# BRK-A         2.149706
# FB          -26.390095
# UNH          -0.138362
# NVDA         -7.559117
# JNJ           0.442428
# V            10.599089
# WMT          -0.640838
# PG           -0.078030
# JPM          -0.926944
# XOM          -0.259801
# MA            9.123334
# CVX           0.551264
# HD           -2.441729
# BAC           1.853285
# KO           -1.775827
# ABBV          1.522151
# PFE          -0.444873
# LLY          -1.037537
# COST         -1.416375
# AVGO          3.005541
# PEP           0.124729
# TMO          -1.522857
# VZ           -3.553876
# DIS           3.348508
# MRK          -0.569554
# CSCO          2.801845
# ABT           0.595241
# CMCSA         3.561770
# ORCL          1.526412
# NKE           2.227509
# ADBE         -9.336481
# DHR          -4.916616
# INTC         -7.041979
# MCD           2.954888
# WFC           1.769147
# CRM           0.718081
# UPS           0.615546
# BMY           1.846447
# TMUS         10.220840
# TXN           2.512069
# PM           -2.255849
# RTX          -1.472697
# QCOM         -4.835280
# MS            2.029260
# UNP          -4.132566

# %% [markdown]
# # Putting data into one dataframe
# - results are very different for each run through

# %%
#Revenue
rev = pd.read_csv(r'revenue.csv')
revdiff = {'rev change %': ((rev.iloc[:, 1] - rev.iloc[:, 2])/rev.iloc[:, 2])*100}
revdata = pd.DataFrame.from_dict(revdiff).join(pricedif1)
data = revdata
#Net Income
income = pd.read_csv(r'netIncome.csv')
incomediff = {'income change %': ((income.iloc[:, 1] - income.iloc[:, 2])/income.iloc[:, 2])*100}
data = data.join(pd.DataFrame.from_dict(incomediff))
#Gross Profit
grossProfit = pd.read_csv('grossProfit.csv')
gpdiff = {'gp change %': ((grossProfit.iloc[:, 1] - grossProfit.iloc[:, 2])/grossProfit.iloc[:, 2])*100}
data = data.join(pd.DataFrame.from_dict(gpdiff))
#Suprise
suprise = pd.read_csv('earnings suprise.csv')
data = data.join(suprise.iloc[:,1])









data
# Out:
#        rev change %  price change(%)  income change %  gp change %  \
# AAPL      48.686420         6.977762        68.507615    54.213339
# MSFT      14.147009         2.849317        -8.485735     9.778662
# GOOG      15.674621         7.367353         9.009294    12.907699
# AMZN      24.004620        13.535914       353.833967    13.982290
# TSLA      28.799884         3.231684        41.681261    32.431694
# BRK-A      1.721378         2.149706       -63.180750   277.748234
# FB        16.066873       -26.390095        11.866435    17.573906
# UNH        1.943680        -0.138362        -4.219409     2.036790
# NVDA       7.602422        -7.559117         3.791070     7.946448
# INTC                -21.11
# MCD                   3.46
# WFC                   8.64
# CRM                  13.50
# UPS                  15.43
# BMY                   0.04
# TMUS                 39.02
# TXN                  16.41
# PM                    5.41
# RTX                   6.93
# QCOM                  6.86
# MS                   21.89
# UNP                   0.78

# %% [markdown]
# # Correlation Tests
# find pearsons and spearman correlation coeff and P-val

# %%
from scipy.stats import pearsonr
from scipy.stats import spearmanr

# *&*&*&*&*&*&*&*&*&*& Revenue *&*&*&*&*&*&*&*&*&*&

corr, pval = pearsonr(data["gp change %"].tolist(), data["price change(%)"].tolist())
print("Revenue v. Price:  the pearson pval is: " + str(pval) + "      the pearsons corr is: "+ str(corr))
corr, pval = spearmanr(data["rev change %"].tolist(), data["price change(%)"].tolist())
print("Revenue v. Price:  the spearman pval is: " + str(pval) + "      the spearman corr is: "+ str(corr))

# *&*&*&*&*&*&*&*&*&*& Gross Profit *&*&*&*&*&*&*&*&*&*&

print("")
corr, pval = pearsonr(data["gp change %"].tolist(), data["price change(%)"].tolist())
print("Gross Profit v. Price:  the pearson pval is: " + str(pval) + "      the pearsons corr is: "+ str(corr))
corr, pval = spearmanr(data["gp change %"].tolist(), data["price change(%)"].tolist())
print("Gross Profit v. Price:  the spearman pval is: " + str(pval) + "      the spearman corr is: "+ str(corr))

# *&*&*&*&*&*&*&*&*&*& Net Income *&*&*&*&*&*&*&*&*&*&

print("")
corr, pval = pearsonr(data["income change %"].tolist(), data["price change(%)"].tolist())
print("Net Income v. Price:  the pearson pval is: " + str(pval) + "      the pearsons corr is: "+ str(corr))
corr, pval = spearmanr(data["income change %"].tolist(), data["price change(%)"].tolist())
print("Net Income v. Price:  the spearman pval is: " + str(pval) + "      the spearman corr is: "+ str(corr))

# *&*&*&*&*&*&*&*&*&*& Suprise *&*&*&*&*&*&*&*&*&*&

print("")
corr, pval = pearsonr(data["Most Recent Suprise"].tolist(), data["price change(%)"].tolist())
print("Suprise v. Price:  the pearson pval is: " + str(pval) + "      the pearsons corr is: "+ str(corr))
corr, pval = spearmanr(data["Most Recent Suprise"].tolist(), data["price change(%)"].tolist())
print("Suprise v. Price:  the spearman pval is: " + str(pval) + "      the spearman corr is: "+ str(corr))
# Out:
# Revenue v. Price:  the pearson pval is: 0.687042917439843      the pearsons corr is: 0.05840310895770906
# Revenue v. Price:  the spearman pval is: 0.5664963036173906      the spearman corr is: 0.0830252100840336
#
# Gross Profit v. Price:  the pearson pval is: 0.687042917439843      the pearsons corr is: 0.05840310895770906
# Gross Profit v. Price:  the spearman pval is: 0.3838012075196312      the spearman corr is: 0.12585834333733492
#
# Net Income v. Price:  the pearson pval is: 0.18101134198451307      the pearsons corr is: 0.19226445126317204
# Net Income v. Price:  the spearman pval is: 0.67372460835961      the spearman corr is: -0.06103241296518607
#
# Suprise v. Price:  the pearson pval is: 0.0006075023083251219      the pearsons corr is: 0.46812528529883146
# Suprise v. Price:  the spearman pval is: 2.254033549682181e-06      the spearman corr is: 0.6126917814918825

# %% [markdown]
# # Scatter Plots

# %%
# *&*&*&*&*&*&*&*&*&*& Revenue *&*&*&*&*&*&*&*&*&*&
plt.scatter(data["gp change %"].tolist(), data["price change(%)"].tolist())
plt.xlabel("Gross Profit (% differnce from last quarter)")
plt.ylabel("Change in Share Price (% differnce)")
plt.show()
# *&*&*&*&*&*&*&*&*&*& Gross Profit *&*&*&*&*&*&*&*&*&*&
plt.scatter(data["gp change %"].tolist(), data["price change(%)"].tolist())
plt.xlabel("Gross Profit (% differnce from last quarter)")
plt.ylabel("Change in Share Price (% differnce)")
plt.show()
# *&*&*&*&*&*&*&*&*&*& Net Income *&*&*&*&*&*&*&*&*&*&
plt.scatter(data["income change %"].tolist(), data["price change(%)"].tolist())
plt.xlabel("Net Income (% differnce from last quarter)")
plt.ylabel("Change in Share Price (% differnce)")
plt.show()
# *&*&*&*&*&*&*&*&*&*& Suprise *&*&*&*&*&*&*&*&*&*&
plt.scatter(data["Most Recent Suprise"].tolist(), data["price change(%)"].tolist())
plt.xlabel("Suprise (% differnce)")
plt.ylabel("Change in Share Price (% differnce)")
plt.show()

data
# Out:
#        rev change %  price change(%)  income change %  gp change %  \
# AAPL      48.686420         6.977762        68.507615    54.213339
# MSFT      14.147009         2.849317        -8.485735     9.778662
# GOOG      15.674621         7.367353         9.009294    12.907699
# AMZN      24.004620        13.535914       353.833967    13.982290
# TSLA      28.799884         3.231684        41.681261    32.431694
# BRK-A      1.721378         2.149706       -63.180750   277.748234
# FB        16.066873       -26.390095        11.866435    17.573906
# UNH        1.943680        -0.138362        -4.219409     2.036790
# NVDA       7.602422        -7.559117         3.791070     7.946448
# JNJ        6.281601         0.442428        29.151895     4.830498
# V          7.623113        10.599089        10.505281     7.884404
# WMT        8.785625        -0.640838        14.718196     5.202524
# PG         3.023896        -0.078030         2.746165     3.168555
# JPM       -2.040162        -0.926944       -11.594977    -2.040162
# XOM       14.932886        -0.259801        31.407407    22.086927
# MA         4.633902         9.123334        -1.449876     4.633902
# CVX        7.776368         0.551264       -17.280314    -1.057805
# HD        -2.990223        -2.441729       -14.104431    -5.579877
# BAC       -3.595554         1.853285        -6.707989    -3.595554
# KO        -5.755826        -1.775827        -6.436956   -11.360264
# ABBV       3.793055         1.522151        28.055731     6.081216
# PFE       -1.905039        -0.444873        46.431781    -0.670762
# LLY       18.118060        -1.037537       -20.148180     9.590041
# COST       3.059786        -1.416375       -20.718563    -0.374357
# AVGO       4.036722         3.005541         6.215316     5.358119
# PEP       25.058200         0.124729        -5.682782    21.566087
# TMO       14.705252        -1.522857       -12.828601    12.792948
# VZ         3.499924        -3.553876        10.465517    -1.629958
# DIS       17.724183         3.348508       -82.679739    17.099952
# MRK        2.790026        -0.569554       195.598706    -0.594750
# CSCO      -1.395349         2.801845        -0.963775    -0.049671
# ABT        4.941435         0.595241        76.689189    10.238278
# CMCSA      0.125421         3.561770         7.945425     2.778476
# ORCL       1.476834         1.526412      -150.752951     1.146202
# NKE       -4.279299         2.227509       -28.655283    -2.800691
# ADBE       3.698297        -9.336481         1.732673     4.079933
# DHR       12.712685        -4.916616        56.401074    14.282450
# INTC       6.961234        -7.041979       -32.243881     2.447422
# MCD       -3.099350         2.954888       -23.773199    -4.965903
# WFC        6.598132         1.769147       -16.646352     6.598132
# CRM        6.746321         0.718081       -12.523364     5.837816
# UPS       19.785197         0.615546       -12.967115     4.806524
# BMY        3.105643         1.846447        53.428202     2.110286
# TMUS       5.916225        10.220840       -38.929088    -1.030028
# TXN        4.070644         2.512069         9.803922     6.281726
# PM        -0.221620        -2.255849        11.680517    -4.144046
# RTX        5.125517        -1.472697        34.980620     9.878517
# QCOM      14.663668        -4.835280        21.479628    18.577514
# MS        -1.552227         2.029260         0.223214    -1.978691
# UNP        3.000359        -4.132566         2.271369     1.195219
#
#        Most Recent Suprise
# AAPL                 11.11
# MSFT                  8.30
# GOOG                 14.99
# AMZN                 61.33
# TSLA                 42.50
# BRK-A                15.40
# FB                   -2.29
# UNH                   1.67
# NVDA                -12.87
# JNJ                   2.69
# V                     8.45
# WMT                   2.00
# PG                    3.91
# JPM                  -3.66
# XOM                   4.59
# MA                    7.31
# CVX                 -17.68
# HD                    0.31
# BAC                   5.26
# KO                   12.50
# ABBV                  6.10
# PFE                   2.70
# LLY                  -0.80
# COST                  8.55
# AVGO                  4.47
# PEP                   0.01
# TMO                   2.52
# VZ                    2.34
# DIS                  85.96
# MRK                  23.29
# CSCO                  5.48
# ABT                  17.69
# CMCSA                 5.48
# ORCL                 -6.00
# NKE                  19.18
# ADBE                 -2.53
# DHR                  -4.15
# INTC                -21.11
# MCD                   3.46
# WFC                   8.64
# CRM                  13.50
# UPS                  15.43
# BMY                   0.04
# TMUS                 39.02
# TXN                  16.41
# PM                    5.41
# RTX                   6.93
# QCOM                  6.86
# MS                   21.89
# UNP                   0.78

# %% [markdown]
# # KNN model

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
#split dataset into train and test data

X = data.drop(columns=['price change(%)'])
y = []

for price in data["price change(%)"].tolist():
    if(price>5):
        y.append(4)
    elif(price>0):
        y.append(3)
    elif(price>-5):
        y.append(2)
    else:
        y.append(1)
knn = KNeighborsClassifier(n_neighbors=1)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.4, stratify=y,random_state=6)
knn.fit(X_train,y_train)
knn.score(X_test, y_test)
# Out:
# 0.5

# %% [markdown]
# # Polynomial Regression

# %%
from sklearn.metrics import r2_score

polyModel = np.poly1d(np.polyfit(data["Most Recent Suprise"].tolist(), data["price change(%)"].tolist(), 5))
polyLine = np.linspace(-20, 75, 400)

plt.scatter(data["Most Recent Suprise"].tolist(), data["price change(%)"].tolist())
plt.plot(polyLine, polyModel(polyLine))
plt.show()

print("the r^2 value is: "+str(r2_score(data["price change(%)"].tolist(), polyModel(data["Most Recent Suprise"].tolist()))))
# Out:
# the r^2 value is: 0.3393332990297394
